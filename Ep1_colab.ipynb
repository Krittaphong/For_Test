# %% [markdown]
# <a href="https://colab.research.google.com/github/Krittaphong/For_Test/blob/main/Ep1_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### learning colab
#  Youtube : [labScience](https://www.youtube.com/labScience-r7d)

# %%
print('Hello World')
# Out:
# Hello World

# %%
# !pip install numpy

# %%
import numpy as np
import matplotlib.pyplot as  plt
import matplotlib.image as mpimg

# %%
array = [1, 2, 3, 4, 5]  # ตัวอย่างการเก็บตัวเลข
print(array)
# Out:
# [1, 2, 3, 4, 5]

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])  # ตัวอย่างการเก็บตัวเลขเป็น matrix 2x3
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img = mpimg.imread('/content/drive/MyDrive/Colab Notebooks/ML/CH4/data dogs/train/f1.JPG') # ใส่ path ของรูปภาพ
plt.imshow(img)
plt.axis('off')  # ไม่แสดงเล้นกรอบแกน
plt.show()

# %%
img = mpimg.imread('/content/fortest1.png') # ใส่ path ของรูปภาพ
plt.imshow(img)
plt.axis('off')  # ไม่แสดงเล้นกรอบแกน
plt.show()
